# %% [markdown]
# # 🧠 Merge Sort with LLM — Hands-on Exercise
#
# In this exercise, you will collaborate with an LLM to design and implement the merge sort algorithm and its corresponding tests. You'll practice writing effective prompts, validating the LLM's output, and reflecting on the quality of both the generated code and tests.
#
# ---
#
# ## 📚 Prerequisites
#
# - Basic understanding of Python programming (functions, lists).
# - Familiarity with the concept of the merge sort algorithm.
# - Experience with prompting Large Language Models (LLMs).
# - Basic knowledge of the `unittest` framework in Python.
#
# ---
#
# ## 📝 Instructions
#
# ### 🧩 Step 1 — Update the Prompt
#
# In the fourth code cell, update the `USER_PROMPT` variable. Your prompt should ask the LLM to write a Python function named `merge_sort` that implements the merge sort algorithm, takes a list of integers, returns a new sorted list, and includes comments.
#
# ---
#
# ### ▶️ Step 2 — Generate and Copy the Function
#
# After running the cell to get the LLM's response, copy the generated `merge_sort` function.
# In the sixth code cell, paste this function into the designated area.
#
# ---
#
# ### 📊 Step 3 — Update Expected Outputs
#
# In the eighth code cell, update the `expected_A` and `expected_B` variables to contain the correctly sorted versions of the input lists.
#
# - `expected_A` should be `[5, 7, 16, 23, 42, 91]`.
# - `expected_B` should be `[-4, 0, 1, 2, 3, 3, 5]`.
#
# ---
#
# ### 🧠 Step 4 — Reflection
#
# In the tenth code cell, answer the four reflection questions about the generated `merge_sort` function by filling in the commented-out sections.
#
# ---
#
# ### ✅ Step 5 — Final Reflection Comment
#
# In the twelfth code cell, add the final reflection comment:
#
# > The edge cases are handled correctly as described above.
#
# ---
#
# ### 🧪 Step 6 — Generate Test Cases
#
# In the fourteenth code cell, update the `USER_PROMPT` again. This time, ask the LLM to generate test cases for the `merge_sort` function using Python's `unittest` framework. The prompt should specify that the tests cover basic functionality, edge cases, and invalid inputs, all within a class named `TestMergeSort`.
#
# After getting the test cases from the LLM, copy the `TestMergeSort` class.
# In the seventeenth code cell, paste the entire class into the designated area.
#
# ---
#
# ### 🔧 Step 7 — Adjust a Test Case
#
# In the test code you just pasted, locate the `test_invalid_string_input_raises_typeerror` method. Modify the call inside this method to:
#
# ```python
# merge_sort(["c", "b", "a"])
# ```
#
#
# ---
# ---
